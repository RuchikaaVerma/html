# %%
import pandas as pd

# %% [markdown]
# Data Ingestion

# %%
df=pd.read_csv('customers-100.csv')
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Index              100 non-null    int64
#  1   Customer Id        100 non-null    object
#  2   First Name         100 non-null    object
#  3   Last Name          100 non-null    object
#  4   Company            100 non-null    object
#  5   City               100 non-null    object
#  6   Country            100 non-null    object
#  7   Phone 1            100 non-null    object
#  8   Phone 2            100 non-null    object
#  9   Email              100 non-null    object
#  10  Subscription Date  100 non-null    object
#  11  Website            100 non-null    object
# dtypes: int64(1), object(11)
# memory usage: 9.5+ KB

# %% [markdown]
# Deduplication

# %%
df=pd.read_csv('customers-100.csv')
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99    False
# Length: 100, dtype: bool

# %%
df=pd.read_csv('customers-100.csv')
df.drop_duplicates()
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
df=pd.read_csv('customers-100.csv')

df["Customer Id"].unique()
# Out:
# array(['DD37Cf93aecA6Dc', '1Ef7b82A4CAAD10', '6F94879bDAfE5a6',
#        '5Cef8BFA16c5e3c', '053d585Ab6b3159', '2d08FB17EE273F4',
#        'EA4d384DfDbBf77', '0e04AFde9f225dE', 'C2dE4dEEc489ae0',
#        '8C2811a503C7c5a', '216E205d6eBb815', 'CEDec94deE6d69B',
#        'e35426EbDEceaFF', 'A08A8aF8BE9FaD4', '6fEaA1b7cab7B6C',
#        '8cad0b4CBceaeec', 'a5DC21AE3a21eaA', 'F8Aa9d6DfcBeeF8',
#        'F160f5Db3EfE973', '0F60FF3DdCd7aB0', '9F9AdB7B8A6f7F2',
#        'FBd0Ded4F02a742', '2FB0FAA1d429421', '010468dAA11382c',
#        'eC1927Ca84E033e', '09D7D7C8Fe09aea', 'aBdfcF2c50b0bfD',
#        'b92EBfdF8a3f0E6', '3B5dAAFA41AFa22', 'EDA69ca7a6e96a2',
#        '64DCcDFaB9DFd4e', '679c6c83DD872d6', '7Ce381e4Afa4ba9',
#        'A09AEc6E3bF70eE', 'aA9BAFfBc3710fe', 'E11dfb2DB8C9f72',
#        '889eCf90f68c5Da', '7a1Ee69F4fF4B4D', 'dca4f1D0A0fc5c9',
#        '17aD8e2dB3df03D', '2f79Cd309624Abb', '6e5ad5a5e2bB5Ca',
#        '7E441b6B228DBcA', 'D3fC11A9C235Dc6', '30Dfa48fe5Ede78',
# ...

# %% [markdown]
# Column Management

# %%
df=pd.read_csv('customers-100.csv')

df["First Name"].unique()
# Out:
# array(['Sheryl', 'Preston', 'Roy', 'Linda', 'Joanna', 'Aimee', 'Darren',
#        'Brett', 'Michelle', 'Carl', 'Jenna', 'Tracey', 'Kristine',
#        'Faith', 'Miranda', 'Caroline', 'Greg', 'Clifford', 'Maxwell',
#        'Kiara', 'Colleen', 'Janet', 'Shane', 'Marcus', 'Dakota',
#        'Frederick', 'Stefanie', 'Kent', 'Jack', 'Tom', 'Gabriel',
#        'Kaitlyn', 'Tammie', 'Nicholas', 'Jordan', 'Bruce', 'Sherry',
#        'Natalie', 'Bryan', 'Wayne', 'Luis', 'Rhonda', 'Joanne',
#        'Geoffrey', 'Gloria', 'Brady', 'Latoya', 'Gerald', 'Samuel',
#        'Patricia', 'Stacie', 'Robin', 'Ralph', 'Phyllis', 'Danny',
#        'Kathy', 'Kelli', 'Lynn', 'Shelley', 'Eddie', 'Chloe', 'Eileen',
#        'Fernando', 'Makayla', 'Virginia', 'Riley', 'Alexandria',
#        'Richard', 'Candice', 'Anita', 'Regina', 'Debra', 'Brittany',
#        'Cassidy', 'Laurie', 'Alejandro', 'Leslie', 'Kathleen', 'Hunter',
#        'Chad', 'Corey', 'Emma', 'Duane', 'Alison', 'Vernon', 'Lori',
# ...

# %%
cols_to_drop = ['Subscription Date', 'Website']
existing_cols = [col for col in cols_to_drop if col in df.columns]
df = df.drop(columns=existing_cols)
print("Columns dropped successfully.")
# Out:
# Columns dropped successfully.

# %%
df = df.rename(columns={'Customer Id': 'ID', 'Country': 'Location'})
print(df.head())
# Out:
#    Index               ID First Name Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano
# 2      3  6F94879bDAfE5a6        Roy     Berry
# 3      4  5Cef8BFA16c5e3c      Linda     Olsen
# 4      5  053d585Ab6b3159     Joanna    Bender
#
#                            Company               City  \
# 0                  Rasmussen Group       East Leonard
# 1                      Vega-Gentry  East Jimmychester
# 2                    Murillo-Perry      Isabelborough
# 3  Dominguez, Mcmillan and Donovan         Bensonview
# 4         Martin, Lang and Andrade     West Priscilla
#
#                      Location                 Phone 1                Phone 2  \
# 0                       Chile            229.077.5154       397.884.0519x718
# 1                    Djibouti              5153435776       686-620-1820x944
# 2         Antigua and Barbuda         +1-539-402-0259    (496)978-3969x58947
# ...

# %%
# Example: Reorder columns
df = df.reindex(columns=['ID', 'Location', 'Age'])

# Example: Reset row index (optional)
df = df.reset_index(drop=True)

# %% [markdown]
# Missing Value Handling

# %%
print(df.isna().sum())
# Out:
# ID            0
# Location      0
# Age         100
# dtype: int64

# %%
df_cleaned = df.dropna()
print(df_cleaned.head())
# Out:
# Empty DataFrame
# Columns: [ID, Location, Age]
# Index: []

# %%
df_filled = df.fillna(0)  # For numeric columns

print(df_filled.head())
# Out:
#                 ID                    Location  Age
# 0  DD37Cf93aecA6Dc                       Chile  0.0
# 1  1Ef7b82A4CAAD10                    Djibouti  0.0
# 2  6F94879bDAfE5a6         Antigua and Barbuda  0.0
# 3  5Cef8BFA16c5e3c          Dominican Republic  0.0
# 4  053d585Ab6b3159  Slovakia (Slovak Republic)  0.0

# %%
df_filled = df.fillna("Unknown")  # For categorical columns
print(df_filled.head())
# Out:
#                 ID                    Location      Age
# 0  DD37Cf93aecA6Dc                       Chile  Unknown
# 1  1Ef7b82A4CAAD10                    Djibouti  Unknown
# 2  6F94879bDAfE5a6         Antigua and Barbuda  Unknown
# 3  5Cef8BFA16c5e3c          Dominican Republic  Unknown
# 4  053d585Ab6b3159  Slovakia (Slovak Republic)  Unknown

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='mean')
df['Age'] = imputer.fit_transform(df[['Age']])
print(df.head())
# Out:
#                 ID                    Location            Age
# 0  DD37Cf93aecA6Dc                       Chile  5.067288e-271
# 1  1Ef7b82A4CAAD10                    Djibouti  5.067288e-271
# 2  6F94879bDAfE5a6         Antigua and Barbuda  5.067288e-271
# 3  5Cef8BFA16c5e3c          Dominican Republic  5.067288e-271
# 4  053d585Ab6b3159  Slovakia (Slovak Republic)  5.067288e-271

# %% [markdown]
# Format Standardization

# %%
df=pd.read_csv('movies.csv')
df.head()
# Out:
#                                 MOVIES         YEAR  \
# 0                        Blood Red Sky       (2021)
# 1  Masters of the Universe: Revelation     (2021– )
# 2                     The Walking Dead  (2010–2022)
# 3                       Rick and Morty     (2013– )
# 4                      Army of Thieves       (2021)
#
#                                         GENRE  RATING  \
# 0      \nAction, Horror, Thriller                 6.1
# 1  \nAnimation, Action, Adventure                 5.0
# 2       \nDrama, Horror, Thriller                 8.2
# 3  \nAnimation, Adventure, Comedy                 9.2
# 4         \nAction, Crime, Horror                 NaN
#
#                                             ONE-LINE  \
# 0  \nA woman with a mysterious illness is forced ...
# 1  \nThe war for Eternia begins again in what may...
# 2  \nSheriff Deputy Rick Grimes wakes up from a c...
# 3  \nAn animated series that follows the exploits...
# ...

# %%
df['MOVIES'] = df['MOVIES'].str.lower()
df
# Out:
#                                    MOVIES         YEAR  \
# 0                           blood red sky       (2021)
# 1     masters of the universe: revelation     (2021– )
# 2                        the walking dead  (2010–2022)
# 3                          rick and morty     (2013– )
# 4                         army of thieves       (2021)
# ...                                   ...          ...
# 9994                       the imperfects     (2021– )
# 9995                               arcane     (2021– )
# 9996                    heart of invictus     (2022– )
# 9997                       the imperfects     (2021– )
# 9998                       the imperfects     (2021– )
#
#                                            GENRE  RATING  \
# 0         \nAction, Horror, Thriller                 6.1
# 1     \nAnimation, Action, Adventure                 5.0
# 2          \nDrama, Horror, Thriller                 8.2
# 3     \nAnimation, Adventure, Comedy                 9.2
# ...

# %%
df['VOTES'] = df['VOTES'].str.strip()#remove extra spaces
df
# Out:
#                                    MOVIES         YEAR  \
# 0                           blood red sky       (2021)
# 1     masters of the universe: revelation     (2021– )
# 2                        the walking dead  (2010–2022)
# 3                          rick and morty     (2013– )
# 4                         army of thieves       (2021)
# ...                                   ...          ...
# 9994                       the imperfects     (2021– )
# 9995                               arcane     (2021– )
# 9996                    heart of invictus     (2022– )
# 9997                       the imperfects     (2021– )
# 9998                       the imperfects     (2021– )
#
#                                            GENRE  RATING  \
# 0         \nAction, Horror, Thriller                 6.1
# 1     \nAnimation, Action, Adventure                 5.0
# 2          \nDrama, Horror, Thriller                 8.2
# 3     \nAnimation, Adventure, Comedy                 9.2
# ...
